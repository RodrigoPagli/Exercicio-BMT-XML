# %%
import os

#Localização do Arquivo
file_name = 'cf79.xml'
full_file = os.path.abspath(os.path.join('data',file_name))

# %%
#Processador A - DOM - Autores
from xml.etree import ElementTree as ET

dom = ET.parse(full_file)
root = dom.getroot()
record = root.findall('RECORD')
raiz = ET.Element('AUTHORS')

#Imprime os dados aqui no Python.
print('ALL AUTHORS')
for r in record:
    authors = r.find('AUTHORS')
    if authors != None:
        author = authors.findall('AUTHOR')
    for a in author:
        b = 1
        print(a.text)

print('ALL TITLES')
for r in record:
    title = r.find('TITLE')
    print('\n',title.text)

for r in record:
    authors = r.find('AUTHORS')
    if authors != None:
        author = authors.findall('AUTHOR')
    for a in author:
        autores = ET.SubElement(raiz,'AUTHOR')
        autores.text = a.text
        
b_xml = ET.tostring(raiz)
with open("autores.xml","wb") as f:
    f.write(b_xml)
# Out:
# ALL AUTHORS
# Jensen-O
# Bak-Pedersen-K
# Larsen-P-K
# Hoiby-N
# Hertz-J-B
# Berg-N-O
# Dahlqvist-A
# Lindberg-T
# Taussig-L-M
# Schiotz-P-O
# Hoiby-N
# Schiotz-P-O
# Hoiby-N
# Permin-H
# Wiik-A
# Schiotz-P-O
# Sorensen-H
# Hoiby-M
# Schiotz-P-O
# Egeskjold-E-M
# Hoiby-N
# Permin-H
# Taussig-L-M
# Lemen-R-J
# Antonowicz-I
# Shwachman-H
# Palin-D
# Underwood-B-A
# Denning-C-R
# Roy-C-C
# Delage-G
# Fontaine-A
# Robitaille-L
# Chartrand-L
# Weber-A
# Morin-C-L
# Lloyd-Still-J-D
# Demers-L-M
# Warwick-W-J
# Hansen-L
# Viela-I
# Matheson-J
# Warwick-W-J
# Viela-I
# Hansen-L-G
# Nussbaum-E
# Boat-T-F
# Wood-R-E
# Doershuk-C-F
# Mischler-E-H
# Chesney-P-J
# Chesney-R-W
# Mazess-R-B
# Strauss-G-D
# Pedersen-S
# Dudovitz-D
# di-Santagnese-P-A
# Davis-P-B
# Fisher-N-L
# Imrie-J-R
# Fagan-D-G
# Sturgess-J-M
# Larsen-G-L
# Barron-R-J
# Cotton-E-K
# Brooks-J-G
# Reid-L-M
# Nelson-L-A
# Callerame-M-L
# Schwartz-R-H
# Feldman-J
# Traver-G-A
# Taussig-L-M
# Zambie-M-F
# Gupta-S
# Lemen-R-J
# Hilman-B
# Waring-W-W
# Sly-R-M
# Stagg-B-H
# Wood-T-P
# Swersky-R-B
# Chang-J-B
# Wisoff-B-G
# Gorvoy-J
# Maybury-B-A
# Blessing-Moore-J
# deWit-S-A
# Lewiston-N-J
# Yeager-A-S
# Greven-Brauns-G
# Mulkens-E
# Maxwell-M
# Redmond-A
# Maxwell-M
# Redmond-A
# Ryley-H-C
# Neale-L-M
# Brogan-T-D
# Bray-P-T
# Jenner-B-M
# Landau-L-I
# Phelan-P-D
# Harries-J-T
# Muller-D-P
# McCollum-J-P
# Lipson-A
# Roma-E
# Norman-A-P
# Hubbard-V-S
# Davis-P-B
# di-SantAgnese-P-A
# Duffner-P-K
# Cohen-M-E
# Forman-Franco-B
# Abramson-A-L
# Gorvoy-J-D
# Stein-T
# Goldberg-R-T
# Isralsky-M
# Shwachman-H
# Bergan-T
# Michalsen-H
# Chapman-J-A
# Goodall-J
# Phelan-P-D
# Carey-W-F
# Hosli-P
# Feery-B-J
# Phelan-P-D
# Gallichio-H-A
# Hampson-A-W
# Bogart-B-I
# Conod-E-J
# Gaerlan-P-F
# Denning-C-R
# Conover-J
# Alhadeff-J-A
# Watkins-P
# Adams-T-H
# Ramsay-G-M
# Wisdom-G-B
# Wijcik-L
# Buchwald-M
# Riordan-J-R
# Riordan-J-R
# Alon-N
# Buchwald-M
# Lappe-M
# MacErlean-D-P
# Gray-B-J
# FitzGerald-M-X
# MacErlean-D-P
# Gray-B-J
# FitzGerald-M-X
# Flower-K-A
# Eden-R-I
# Lomax-L
# Mann-N-M
# Burgess-J
# Pryor-J-A
# Webber-B-A
# Hodson-M-E
# Batten-J-C
# Chapman-J-A
# Goodall-J
# Bradley-J-A
# Axon-A-T
# Hill-G-L
# Zapletal-A
# Houstek-J
# Samanek-M
# Vavrova-V
# Srajer-J
# Coates-A-L
# Boyce-P
# Muller-D
# Mearns-M
# Godfrey-S
# Sams-C-A
# Berger-H-J
# Zaret-B-L
# Hoogkamp-Korstanje-J-A
# Westerdaal-N-A
# Allen-H-D
# Taussig-L-M
# Gaines-J-A
# Sahn-D-J
# Goldberg-S-J
# Lieberman-J
# Kaneshiro-W
# Weng-T-R
# Spence-J-A
# Polgar-G
# Nyboer-J
# Keens-T-G
# Mansell-A
# Krastins-I-R
# Levison-H
# Bryan-A-C
# Hyland-R-H
# Zamel-N
# Hirschfeld-S-S
# Fleming-D-G
# Doershuk-C
# Liebman-J
# Price-J-F
# Weller-P-H
# Harper-S-A
# Matthew-D-J
# Ganier-M
# Lieberman-P
# Kutty-K-M
# Guha-A-K
# Chandra-R-K
# Vaze-D
# Chalmers-R-A
# Valman-H-B
# Liberman-M-M
# Shwachman-H
# Mohmoodian-A
# Willcox-P
# Casola-L
# Di-Matteo-G
# Romano-M
# Rutigliano-B
# Mastella-G
# Butterworth-J
# Duncan-J-J
# Ben-Yoseph-Y
# Defranco-C-L
# Nadler-H-L
# Scanlin-T-F
# Matacic-S-S
# Glick-M-C
# Lake-C-R
# Davis-P-B
# Ziegler-M
# Kopin-I-J
# Butterworth-J
# Guy-G-J
# Carswell-F
# Oliver-J
# Silverman-M
# Super-M
# van-Schalkwyk-D-J
# Koheil-A
# Corey-M
# Forstner-G
# Crass-J-R
# LHeureux-P
# Loken-M
# Clamp-J-R
# Gough-M
# Pennington-J-E
# Rosenlund-M-L
# Walsh-E-P
# Scott-D-A
# Kritchevsky-D
# Houstek-J
# Zapletal-A
# Samanek-M
# Vavrova-V
# Harris-A
# MacLeod-S-M
# Walsh-Platt-M
# Rao-G-J
# Nadler-H-L
# Paporisz-U
# Posselt-H-G
# Wonne-R
# Ristow-W
# Roser-D
# Knothe-H
# Bender-S-W
# Hosli-P
# Vogt-E
# Kraemer-R
# Rudeberg-A
# Klay-M
# Rossi-E
# Strauss-R-G
# Cusack-D
# Cannon-D
# Skrabanek-P
# Powell-D
# Tucker-R-D
# Hudrlik-T-R
# Gibbs-G-E
# Christensen-M-B
# Sorensen-R-U
# Stern-R-C
# Chase-P
# Polmar-S-H
# Thomsen-J
# Friis-B
# Afzelius-B-A
# Barry-M-M
# Thomsen-J
# Friis-B
# Jensen-K
# Bak-Pedersen-K
# Larsen-P-K
# Hughes-D-T
# Pines-A
# Percival-A
# Stille-W
# Frydman-M-I
# Kerner-J
# Harvey-B
# Lewiston-N
# Spicer-K-M
# Allen-R-C
# Hallett-D
# Buse-M-G
# Seale-T-W
# Thirkill-H
# Tarpay-M
# Flux-M
# Rennert-O-M
# Lloyd-J-K
# Francis-D-E
# Vymola-F
# Trojanova-M
# Pillich-J
# Lochmann-O
# Thomassen-M-J
# Demko-C-A
# Boxerbaum-B
# Stern-R-C
# Kuchenbrod-P-J
# Pennington-J-E
# Wolff-S-M
# Puziss-M
# Dreisin-R-B
# Mostow-S-R
# Bria-W-F
# Kenny-W-R
# Nevin-G-B
# Nevin-N-C
# Redmond-A-O
# Soter-N-A
# Mihm-M-C-Jr
# Colten-H-R
# Herrod-H-G
# Amos-D-B
# Spock-A
# Newman-A-J
# Ansell-B-M
# Worley-L
# Poole-C
# Valdes-Depena-M
# Mihalas-L-S
# Mitchell-I
# Malis-F
# Fric-P
# Kasafirek-E
# Jodl-J
# Vavrova-V
# Slaby-J
# Cox-K-L
# Isenberg-J-N
# Osher-A-B
# Dooley-R-R
# Church-J-A
# Keens-T-G
# Wang-C-I
# ONeal-M
# Richards-W
# Church-J-A
# Keens-T-G
# Wang-C-I
# ONeal-M
# Richards-W
# Fellows-K-E
# Khaw-K-T
# Schuster-S
# Shwachman-H
# Schwachman-H
# Hubbard-V-S
# Farrell-P-M
# di-SantAgnese-P-A
# Hahn-T-J
# Squires-A-E
# Halstead-L-R
# Strominger-D-B
# Weisman-Y
# Reiter-E
# Stern-R-C
# Root-A
# Huff-D-S
# Huang-N-N
# Arey-J-B
# Chipps-B-E
# Alderson-P-O
# Roland-J-M
# Yang-S
# van-Aswegen-A
# Martinez-C-R
# Rosenstein-B-J
# Finkelstein-E
# Hall-K
# Loening-Baucke-V-A
# Mischler-E
# Myers-M-G
# Rosenfeld-R
# Spigelblatt-L
# Chicoine-R
# Porter-R-C
# Cloutier-M-M
# Brasfield-D-M
# Mangos-J-A
# Miale-T
# Tiller-R-E
# Chase-H-P
# Long-M-A
# Lavin-M-H
# Moss-T-J
# Austin-G-E
# Moss-A-J
# Sacher-M
# Shmerling-D-H
# Fischer-E-G
# Shwachman-H
# Wepsic-J-G
# Venugopal-S
# Shandling-B
# Morrissey-S-M
# Tymvios-M-C
# Bond-C-E
# Fraser-P-A
# Smaje-L-H
# Hicks-J-M
# Priest-J-B
# Heinrich-H-C
# Gabbe-E-E
# Icagic-F
# Oppenheimer-E-H
# Rosenstein-B-J
# King-D-N
# Heeley-A-F
# Walsh-M-P
# Kuzemko-J-A
# Harris-A
# Benson-P-F
# Fensom-A-H
# Applegarth-D-A
# Davidson-A-G
# Kirby-L-T
# Bridges-M
# Sorensen-P
# Wong-L-T
# Hardwick-D-F
# Lieberman-J
# Brock-D-J
# Hayward-C
# Phillips-B
# Davis-J-A
# Goode-M
# Romer-F-K
# Faber-V
# Koch-C
# Pedersen-F-K
# Friis-B
# Johansen-K-S
# Taudorff-E
# Crossley-J-R
# Elliott-R-B
# Smith-P-A
# Crossley-J-R
# Elliott-R-B
# Smith-P-A
# Dandona-P
# Hodson-M
# Bell-J
# Ramdial-L
# Batten-J-C
# Walsh-M-M
# Nadler-H-L
# Patrick-A-D
# Ellis-R-B
# Patrick-A-D
# Ellis-R-B
# Hirani-S
# Winchester-B-G
# Dann-L-G
# Blau-K
# Hosli-P
# Vogt-E
# Lam-L-F
# Shapiro-B-L
# Sordelli-D-O
# Cassino-R-J
# Pivetta-O-H
# Shier-W-T
# Danes-B-S
# Sutanto-E
# Hahnel-R
# Hosli-P
# Phelan-P-D
# Allan-J-L
# Landau-L-I
# Barnes-G-L
# Carey-W-F
# Pollard-A-C
# Weller-P-H
# Bush-E
# Preece-M-A
# Norman-A-P
# Matthew-D-J
# Kerrebijn-K-F
# Veentjer-M-A
# Water-E-B
# Kraemer-R
# Rudeberg-A
# Rossi-E
# Flower-K-A
# Mann-N-M
# Eden-R-I
# Dab-I
# Alexander-F
# Bakken-A-F
# Motzfeldt-C
# Konradova-V
# Vavrova-V
# Tomanek-A
# Houstek-J
# di-SantAgnese-P-A
# Davis-P-B
# Roscher-A
# Wiesmann-U-N
# Hadorn-B
# Aggett-P-J
# Thorn-J-M
# Delves-H-T
# Harries-J-T
# Clayton-B-E
# Hamdi-I
# Bloom-A-L
# Goodchild-M-C
# Dodge-J-A
# Hosli-P
# Kollberg-H
# Vogt-E
# Casola-L
# Di-Matteo-G
# Mastella-G
# Rutigliano-B
# Romano-M
# Starkey-B-J
# Goodchild-M-C
# Carswell-F
# Oliver-J
# Silverman-M
# Leupold-W
# Dietzsch-H-J
# Baran-D
# Wolter-R
# Bourdoux-P
# Ermans-A-M
# Super-M
# Morrissey-S-M
# Tymvios-M-C
# Berg-U
# Kallner-A
# Kusoffsky-E
# Strandvik-B
# Price-J-F
# Weller-P-H
# Harper-S-A
# Matthew-D-J
# Pryjma-J
# Rudnik-J
# Zebrak-J
# Herman-T
# Gawe-J
# Schiotz-P-O
# Sorensen-H
# Hoiby-N
# Hein-J
# David-A
# Grimm-J
# Gottschalk-B
# Hoiby-N
# Hertz-J-B
# Prosser-R
# Michalsen-H
# Rolla-G
# Melsen-B
# Sonju-T
# Ryley-H-C
# Torriani-R
# Chassot-J
# Stocker-F
# Weber-J-W
# Di-Matteo-G
# Romano-M
# Mastella-G
# Castellani-E
# Rutigliano-B
# Casola-L
# Kulczycki-L-L
# Wientzen-R
# Paporisz-U
# Posselt-H-G
# Wonne-R
# Ristow-W
# Roser-D
# Knothe-H
# Bender-S-W
# Guggenbichler-J-P
# Kienel-G
# Stephan-U
# Davidson-A-G
# Applegarth-D-A
# Wong-L-T
# Davidson-A-G
# Applegarth-D-A
# Wong-L-T
# Feigal-R-J
# Shapiro-B-L
# Columbo-J-L
# Gibbs-G-E
# Iveson-Iveson-J
# Clement-M
# Jankowski-L-W
# Beaudry-P-H
# Chu-J-Y
# Chu-J-Y
# Sherman-A-H
# Amoore-J-E
# Weigel-V
# Vawter-G-F
# Shwachman-H
# Ghadially-F-N
# Cox-D-W
# Talamo-R-C
# Gurwitz-D
# Corey-M
# Francis-P-W
# Crozier-D
# Levison-H
# Pearson-R-D
# Lubin-A-H
# Mawhinney-T-P
# Feather-M-S
# Martinez-J-R
# Barbero-G-J
# Russell-D-H
# Rosenblum-M-G
# Beckerman-R-C
# Durie-B-G
# Taussig-L-M
# Barnett-D-R
# Martinez-J-R
# Martinez-A-M
# Garrett-L
# Korman-P
# Will-P-C
# Boat-T-F
# Hopfer-U
# Feigal-R-J
# Shapiro-B-L
# Van-Leuven-F
# Cassiman-J-J
# Van-Den-Berghe-H
# Thomassen-M-J
# Boxerbaum-B
# Demko-C-A
# Kuchenbrod-P-J
# Dearborn-D-G
# Wood-R-E
# Pivetta-O-H
# Labal-M-L
# Sordelli-D-O
# Romeo-G
# Parsons-M
# Bossen-A
# Blessing-Moore-J
# Cavalli-Sforza-L-L
# Wolf-R-O
# Taussig-L
# Gabridge-M-G
# Bright-M-J
# Agee-C-C
# Nickerson-J-M
# Henderson-N-S
# Verdugo-P
# Hinds-T-R
# Vincenzi-F-F
# Tucker-R-D
# Gibbs-G-E
# Christensen-M-B
# Tully-G-W
# Nevin-G-B
# Young-I-R
# Nevin-N-C
# Wilson-G-B
# Nagy-E-C
# Khan-S
# Sturgess-J-M
# Chase-H-P
# Cotton-E-K
# Elliott-R-B
# Brasfield-D
# Hicks-G
# Soong-S
# Tiller-R-E
# Lloyd-Still-J-D
# Simon-S-H
# Wessel-H-U
# Gibson-L-E
# Beckerman-R-C
# Taussig-L-M
# Nezelof-C
# LeSec-G
# Phelps-D-L
# Beckerman-R-C
# Pryor-J-A
# Webber-B-A
# Martodam-R-R
# Baugh-R-J
# Twumasi-D-Y
# Liener-I-E
# Shapiro-B-L
# Feigal-R-J
# Lam-L-F
# Mangos-J-A
# Gluckson-M-M
# Denning-C-R
# Gluckson-M-M
# Denning-C-R
# Swan-H-A
# Chappell-J-S
# Friis-B
# Gawel-J
# Rudnik-J
# Pryjma-J
# Zebrak-J
# Hauszka-J
# Rudnik-I
# Majewska-Zalewska-H
# Zebrak-J
# Herman-T
# Werys-R
# Pryjma-J
# Gawel-J
# Kurz-J-B
# Perkins-J-P
# Buchwald-M
# Shapiro-B-L
# Lam-L-F
# Fast-L-H
# Howie-A-D
# Stack-B-H
# Frydman-M-I
# Wood-R-E
# van-Vroonhoven-T-J
# Molenaar-J-C
# Bowman-B-H
# Landau-L-I
# Mellis-C-M
# Phelan-P-D
# Bristowe-B
# McLennan-L
# Lieberman-J
# Costea-N-V
# Jakulis-V-J
# Kaneshiro-W
# Bohles-H
# Heid-H
# Stehr-K
# Fekl-W
# ALL TITLES
#
#  'Rusters'.  The corrosive action of palmar sweat: I. Sodium chloride
# in sweat.
#
#  Inflammatory middle ear diseases in patients with cystic fibrosis.
#
#  Precipitating antibodies against Escherichia coli, Bacteroides
# fragilis ss.  thetaiotaomicron and Pseudomonas aeruginosa in serum
# from normal persons and cystic fibrosis patients, determined by
# means of crossed immunoelectrophoresis.
#
#  Exocrine pancreatic insufficiency, small intestinal dysfunction and
# protein intolerance.  A chance occurrence or a connection?.
#
#  Increased intracranial pressure in infants with cystic fibrosis
# [letter].
#
#  Precipitating antibodies against Haemophilus influenzae and
# Staphylococcus aureus in sputum and serum from patients with cystic
# fibrosis.
#
#  IgA and IgG antibodies against surface antigens of Pseudomonas
# aeruginosa in sputum and serum from patients with cystic fibrosis.
#
#  Activated complement in the sputum from patients with cystic
# fibrosis.
#
#  Autoantibodies in serum and sputum from patients with cystic
# fibrosis.
#
#  Chronic obstructive lung disease.
#
#  Meconium in health and in disease.
#
#  The effect of oral zinc supplementation on plasma levels of vitamin
# A and retinol-binding protein in cystic fibrosis.
#
#  The fecal microflora and bile acids in children with cystic fibrosis.
#
#  Serum glycine-conjugated bile acids in pediatric hepatobiliary
# disorders.
#
#  Comparison of the chloride electrode and gravimetric chloride
# titration sweat tests.
#
#  Comparison of the errors due to the use of gauze and the use of
# filter paper in the gravimetric chloride titration sweat test.
#
#  Cystic fibrosis with acute hypoelectrolytemia and metabolic
# alkalosis in infancy.
#
#  Demineralization in cystic fibrosis detected by direct photon
# absorptiometry.
#
#  Psychosocial support for adults with cystic fibrosis: a group
# approach.
#
#  Cystic fibrosis in adults.  75 cases and a review of 232 cases in
# the literature.
#
#  Genetic counseling and prenatal diagnosis of cystic fibrosis
# [letter].
#
#  Quantitative evaluation of the development of the exocrine pancreas
# in cystic fibrosis and control infants.
#
#  A comparative study of inhaled atropine sulfate and isoproterenol
# hydrochloride in cystic fibrosis.
#
#  The pulmonary circulation: remodeling in growth and disease.  The
# 1978 J. Burns Amberson lecture.
#
#  Aspergillosis and atopy in cystic fibrosis.
#
#  Maximal expiratory flows after postural drainage.
#
#  Relationship between response to exercise and allergy in patients
# with cystic fibrosis.
#
#  Radioimmunoassay of trypsin.  A new aid in the assessment of
# pancreatic function.
#
#  Endobronchial balloon tamponade of hemoptysis in patients with
# cystic fibrosis.
#
#  Antimicrobial susceptibilities of rough, smooth, and mucoid colony
# types of Pseudomonas isolated from cystic fibrosis patients.
#
#  Results of 10 years of screening of newborn infants for inherited
# metabolic diseases in the province of Limburg (Belgium).
#
#  Comparative trial of manual and mechanical percussion technique with
# gravity-assisted bronchial drainage in patients with cystic fibrosis.
#
#  Paediatric Research Society.  Plymouth, 15 and 16 September 1978:
# Abstracts.
#
#  Screening for cystic fibrosis in the newborn by meconium analysis.
#
#  Pulmonary candidiasis in cystic fibrosis.
#
#  Intestinal bile salts in cystic fibrosis: studies in the patient and
# experimental animal.
#
#  Possible hazard of timed-release aspirin in a patient with
# pancreatic insufficiency.
#
#  Cystic fibrosis with brain abscess.
#
#  Cystic fibrosis and hearing loss.
#
#  Vocational development and adjustment of adolescents with cystic
# fibrosis.
#
#  Pharmacokinetics of azlocillin in children with cystic fibrosis.
#
#  Dying children need help too.
#
#  Cystic fibrosis: is it relevant to family practitioners?.
#
#  Inhibition of Tamm-Horsfall glycoprotein induction of alkaline
# phosphatase in cystic fibrosis fibroblasts by medium conditioned by
# normal cells.
#
#  Antibody responses to influenza virus vaccine in patients with
# cystic fibrosis.
#
#  Biological activities of cystic fibrosis serum.  III.  CF serum
# induced uptake of 45Ca++ by rabbit tracheal explants.
#
#  Differential concanavalin A binding of cystic fibrosis and normal
# liver alpha-L-fucosidase.
#
#  Enzyme immunoassay of albumin as an aid to the diagnosis of cystic
# fibrosis in the newborn human [proceedings].
#
#  Induction of alkaline phosphatase in cultured human fibroblasts.
# Comparison of normal cells and those from patients with cystic
# fibrosis.
#
#  Plasma membrane lipids of human diploid fibroblasts from normal
# individuals and patients with cystic fibrosis.
#
#  2. Theories of genetic causation in human disease.
#
#  Bronchial artery embolization in the control of massive haemoptysis.
#
#  Cystic fibrosis in adults [editorial].
#
#  New mechanical aid to physiotherapy in cystic fibrosis.
#
#  Evaluation of the forced expiration technique as an adjunct to
# postural drainage in treatment of cystic fibrosis.
#
#  Dying children need help too.
#
#  Nocturnal elemental diet for retarded growth in a patient with
# cystic fibrosis.
#
#  Lung function abnormalities in cystic fibrosis and changes during
# growth.
#
#  The role of nutritional status, airway obstruction, hypoxia and
# abnormalities in serum lipid composition in limiting exercise
# tolerance in children with cystic fibrosis.
#
#  One breath at a time: a family teaching program for children with
# cystic fibrosis.
#
#  Noninvasive radionuclide assessment of right ventricular performance
# in man.
#
#  In vitro susceptibility of pseudomonas to four
# beta-lactamantibiotics (ampicillin, cephalothin, carbenicillin,
# piperacillin), to four aminoglycosides (kanamycin, amikacin,
# gentamicin, tobramycin) and to colimycin.
#
#  Echocardiographic profiles of the long-term cardiac changes in
# cystic fibrosis.
#
#  Lymphocytic acid-hydrolases and response to mitogens in cystic
# fibrosis.
#
#  Measurement of regional lung function by tetrapolar electrical
# impedance plethysmography.
#
#  Evaluation of the single-breath diffusing capacity in asthma and
# cystic fibrosis.
#
#  Echocardiographic abnormalities in patients with cystic fibrosis.
#
#  Response to bronchial provocation and exercise in children with
# cystic fibrosis.
#
#  IgE mediated hypersensitivity to pancreatic extract (PE) in parents
# of cystic fibrosis (CF) children.
#
#  A study of erythrocyte fatty acids, adenosinetriphosphatase and
# acetylcholinesterase in cystic fibrosis.
#
#  Measurement of 4-hydroxyphenylacetic aciduria as a screening test
# for small-bowel disease.
#
#  Quality of sweat test performance in the diagnosis of cystic
# fibrosis.
#
#  Secretion of beta-N-acetylglucosaminidase isoenzymes by cultured
# cystic fibrosis fibroblasts.
#
#  Glycosidases in serum of cystic fibrosis patients.
#
#  Carboxypeptidase B activity of cultured skin fibroblasts and
# relationship to cystic fibrosis.
#
#  Decreased sialic acid and altered binding to lectins of purified
# alpha 2-macroglobulin from patients with cystic fibrosis.
#
#  Abnormal distribution of alpha-L-fucosidase in cystic fibrosis:
# decreased activity in serum.
#
#  Electrolytes and norepinephrine levels in blood of patients with
# cystic fibrosis.
#
#  Primary amniotic fluid cell, skin fibroblast and liver
# alpha-L-fucosidase and its relation to cystic fibrosis.
#
#  Allergy in cystic fibrosis.
#
#  Heterozygote advantage in cystic fibrosis: mosquito tests.
#
#  Deficiency of serum carboxypeptidase B-like (anaphylatoxin
# inactivator, carboxypeptidase N) activity in sera from patients with
# cystic fibrosis.
#
#  False-positive 111In-labeled leukocyte scan in cystic fibrosis.
#
#  Study of the oligosaccharide units from mucus glycoproteins of
# meconium from normal infants and from cases of cystic fibrosis with
# meconium ileus.
#
#  Pseudomonas aeruginosa infection: pathogenesis and therapy.
#
#  Lipids in cystic fibrosis.
#
#  Obstruction of the respiratory pathways, its evaluation by methods
# of functional examination of the lungs and development in patients
# with cystic fibrosis.
#
#  Prenatal diagnosis of cystic fibrosis [letter].
#
#  Clinical pharmacology in a paediatric hospital.
#
#  Protease deficiency in plasma of patients with cystic fibrosis.
# Reduced reaction of 4-methylumbelliferylguanidinobenzoate with
# plasma of patients with cystic fibrosis.
#
#  Evaluation of long term tobramycin therapy in patients with cystic
# fibrosis and advanced pulmonary disease.
#
#  Cystic fibrosis: decreased thermostability of alpha-mannosidase in
# crude extracellular fluids of patients and carriers.
#
#  Relationship between clinical conditions, radiographic findings and
# pulmonary functions in patients with cystic fibrosis.
#
#  Complement in cystic fibrosis.
#
#  Substance P plasma levels in pregnancy and in various clinical
# disorders.
#
#  The effect of serum from patients with pancreatic disease on the
# short circuit current of rat jejunum.
#
#  Defective cellular immunity to gram-negative bacteria in cystic
# fibrosis patients.
#
#  High dosage tobramycin treatment of children with cystic fibrosis.
# Bacteriological effect and clinical ototoxicity.
#
#  The immotile-cilia syndrome and other ciliary diseases.
#
#  Cystic fibrosis.
#
#  Tobramycin ototoxicity.  Repeated courses of high dosage treatment
# in children with cystic fibrosis.
#
#  Round table discussion--treatment of lower respiratory tract
# infections with co-trimoxazole.
#
#  Epidemiology of cystic fibrosis: a review.
#
#  The impact of grief: a retrospective study of family function
# following loss of a child with cystic fibrosis.
#
#  Synthesis of hemoglobin Aic and related minor hemoglobin by
# erythrocytes.  In vitro study of regulation.
#
#  Serotypes and antibiotic susceptibilities of Pseudomonas aeruginosa
# isolates from single sputa of cystic fibrosis patients.
#
#  Dietary problems associated with the care of chronically sick
# children.
#
#  Inborn errors of metabolism: the need for sugar.
#
#  Therapeutic possibilities in Pseudomonas infections.
#
#  Multiple of isolates of Pseudomonas aeruginosa with differing
# antimicrobial susceptibility patterns from patients with cystic
# fibrosis.
#
#  Summary of a workshop on infections in patients with cystic fibrosis.
#
#  Sulfhydryl-mediated depression of ciliary activity: an adverse
# effect of acetylcysteine.
#
#  Adult cystic fibrosis: a new therapeutic challenge for the primary
# care physician.
#
#  Cystic fibrosis in Northern Ireland.
#
#  Cutaneous necrotizing venulitis in patients with cystic fibrosis.
#
#  HLA determinants in families with more than one member with cystic
# fibrosis [letter].
#
#  Episodic arthritis in children with cystic fibrosis.
#
#  Failure to thrive, anemia, and anasarca.
#
#  Bronchial hyperreactivity in cystic fibrosis [letter].
#
#  A peroral test of pancreatic insufficiency with
# 4-(N-acetyl-L-tyrosyl)aminobenzoic acid in children with cystic
# fibrosis.
#
#  The effect of cimetidine on maldigestion in cystic fibrosis.
#
#  Normal neutrophil and monocyte chemotaxis in patients with cystic
# fibrosis.
#
#  Hyperuricemia in cystic fibrosis [letter].
#
#  Bronchial artery embolization in cystic fibrosis; technique and
# long-term results.
#
#  Reliability of sweat test in cystic fibrosis [letter].
#
#  25-Hydroxycholecalciferol levels in patients with cystic fibrosis.
#
#  Reduced serum 25-hydroxyvitamin D concentration and disordered
# mineral metabolism in patients with cystic fibrosis.
#
#  Serum concentrations of 25-hydroxyvitamin D and
# 24,25-dihydroxyvitamin D in patients with cystic fibrosis.
#
#  Atypical cystic fibrosis of the pancreas with normal levels of sweat
# chloride and minimal pancreatic lesions.
#
#  Noninvasive evaluation of ventricular function in cystic fibrosis.
#
#  Aminoglycoside clearance in patients with cystic fibrosis [letter].
#
#  A placebo-controlled trial of cephalexin therapy in the ambulatory
# management of patients with cystic fibrosis.
#
#  False positive sweat test, malnutrition, and the Mauriac syndrome.
#
#  Cystic fibrosis in two black children with sickle cell anemia.
#
#  Cystic fibrosis and malnutrition.
#
#  Preatherosclerotic aortic lesions in cystic fibrosis.
#
#  PABA-test for diagnosis of exocrine pancreatic insufficiency
# [letter].
#
#  Brain abscess and cystic fibrosis.
#
#  Meconium ileus: laparotomy without resection, anastomosis, or
# enterostomy.
#
#  The effect of histamine, metiamide and cystic fibrosis factor on the
# electrophysiological properties of the frog's gastric mucosa
# [proceedings].
#
#  The chronically ligated submandibular salivary duct of the rabbit as
# a possible model for cystic fibrosis [proceedings].
#
#  Sweat tests [letter].
#
#  The sweat test for cystic fibrosis [letter].
#
#  Immunoreactive serum trypsin in diseases of the pancreas.
#
#  Differential pathology of nasal polyps in cystic fibrosis and atopy.
#
#  Sensitive trypsin assay for dried-blood specimens as a screening
# procedure for early detection of cystic fibrosis.
#
#  Detection of cystic fibrosis with plasma hydrolases [letter].
#
#  Dried blood spot screening for cystic fibrosis [letter].
#
#  Age dependence of serum angiotensin-converting enzyme activity
# [letter].
#
#  Methylumbelliferyl-guanidinobenzoate reactive proteases and prenatal
# diagnosis of cystic fibrosis [letter].
#
#  Screening for cystic fibrosis [letter].
#
#  Serum-angiotensin-converting-enzyme in chronic granulomatous disease
# [letter].
#
#  Dried-blood spot screening for cystic fibrosis in the newborn.
#
#  Allergy and bronchial hyperreactivity in cystic fibrosis [editorial].
#
#  Serum-immunoreactive-trypsin concentrations in cystic fibrosis
# [letter].
#
#  Methylumbelliferyl-guanidinobenzoate reactive proteases in amniotic
# fluid: possible marker for cystic fibrosis [letter].
#
#  Plasma hydrolases in cystic fibrosis [letter].
#
#  Mechanical chest physiotherapy [editorial].
#
#  Detection of cystic fibrosis homozygotes and heterozygotes with
# plasma [letter].
#
#  Arginine esterase in amniotic fluid: possible marker for cystic
# fibrosis [letter].
#
#  Detection of cystic fibrosis homozygotes and heterozygotes with
# plasma.
#
#  Differential incorporation of 3H-thymidine into DNA in cultured skin
# fibroblasts derived from patients with cystic fibrosis and controls.
#
#  Animal model for cystic fibrosis: pulmonary clearance of
# Staphylococcus aureus in mice treated with reserpine.
#
#  Increased resistance to influenza as a possible source of
# heterozygote advantage in cystic fibrosis.
#
#  Pathogenesis of cystic fibrosis: possible importance of alteration
# in epithelial surface topography.
#
#  Alkaline phosphatase induction in cystic fibrosis fibroblasts
# [letter].
#
#  Improved survival of patients with cystic fibrosis.
#
#  Alkaline phosphatase induction in cystic fibrosis fibroblasts
# [letter].
#
#  The short-term effects of chest physiotherapy on lung function tests
# in children with cystic fibrosis.
#
#  Effect of four physiotherapy schedules on pulmonary function in
# children with cystic fibrosis.
#
#  Relationship between clinical conditions, chest radiographic
# findings and respiratory function tests in cystic fibrosis.
#
#  A new percussion aid for cystic fibrosis patients.
#
#  The mechanism of autogenic drainage studied with flow volume curves.
#
#  Intestinal lactase deficiency in newborns with cystic
# fibrosis--dietary consequences.
#
#  Ultrastructure of the bronchial epithelium in children with cystic
# fibrosis.
#
#  Recent research in cystic fibrosis.
#
#  Relevance of second messengers in cystic fibrosis.
#
#  Trace element malabsorption in exocrine pancreatic insufficiency.
#
#  Prostaglandins and cystic fibrosis.
#
#  Operational definition of cystic fibrosis.  I.
#
#  Alpha-glucosidase in cystic fibrosis.
#
#  Postprandial total serum bile acid concentrations in cystic fibrosis.
#
#  The cystic fibrosis gene, IgE and IgG4.
#
#  Bronchial reactivity in children with cystic fibrosis and other
# recurrent or chronic bronchopulmonary diseases.
#
#  Increased serum TSH response to TRH in cystic fibrosis.
#
#  Factors influencing the frequency of cystic fibrosis in South West
# Africa.
#
#  The effect of cystic fibrosis and non-cystic fibrosis plasma on
# electrophysiological responses in isolated frog gastric mucosa.
#
#  Fatty acid supplementation in cystic fibrosis.
#
#  Bronchial provocation tests in cystic fibrosis.
#
#  The local immune status in cystic fibrosis.
#
#  Complement activation and pulmonary inflammation in CF patients.
#
#  Protein, IgA, secretory IgA, IgG and electrolytes as parameters of
# parotid gland function in children with cystic fibrosis.
#
#  Precipitating antibodies against E. coli, B. fragilis, and P.
# aeruginosa in CF patients and normal persons determined by means of
# crossed immunoelectrophoresis.
#
#  Screening for cystic fibrosis in the newborn.
#
#  Sulphated glycoproteins in the pancreas.
#
#  An evaluation of the meconium 'lactase test' for the detection of
# cystic fibrosis in the newborn.
#
#  Two children with cystic fibrosis and myocardial fibrosis.
#
#  Chemical comparison of normal and cystic fibrosis meconium: a
# quantitative and qualitative analysis of carbohydrate splitting
# enzymes.
#
#  The use and abuse of antibiotics, including in management of
# pulmonary manifestations in cystic fibrosis.
#
#  Long-term tobramycin therapy in patients with cystic fibrosis and
# advanced pulmonary disease.
#
#  Bioavailability of oral antibiotics in cystic fibrosis.
#
#  Progress in screening.
#
#  Diagnosing cystic fibrosis in adults [letter].
#
#  Case records of the Massachusetts General Hospital.  Weekly
# clinicopathological exercises.  Case 8-1979.
#
#  Mitochondrial calcium uptake and oxygen consumption in cystic
# fibrosis.
#
#  Cystic fibrosis and erroneous sweat tests.
#
#  Cystic fibrosis: a disease of unknown causes.
#
#  Prone immersion physical exercise therapy in three children with
# cystic fibrosis: a pilot study.
#
#  Anemia, hypoproteinemia and edema in an infant with cystic fibrosis.
#
#  Serum vitamin D and related mineral metabolism in cystic fibrosis.
#
#  The pyridine scale for clinical measurement of olfactory threshold:
# a quantitative reevaluation.
#
#  Cystic fibrosis in adults: an autopsy study.
#
#  Invited review.  The technique and scope of electron-probe X-ray
# analysis in pathology.
#
#  Genetic aspects of pediatric lung disease.
#
#  Perspectives in cystic fibrosis.
#
#  Increased heparin binding in cystic fibrosis: a reflection of
# altered glycoprotein biosynthesis?.
#
#  The chronically reserpinized rat as an animal model for cystic
# fibrosis: I. Acute effect of isoproterenol and pilocarpine upon
# pulmonary lavage fluid.
#
#  Altered polyamine metabolism in cystic fibrosis.
#
#  Chronically reserpinized rat as a model for cystic fibrosis: Na+
# transport inhibitory effect in submaxillary saliva.
#
#  Evidence against a specific effect of serum from patients with
# cystic fibrosis on sodium-dependent glucose transport in the rat
# jejunum.
#
#  Altered intracellular calcium in fibroblasts from patients with
# cystic fibrosis and heterozygotes.
#
#  Anomalous alpha 2-macroglobulin-protease complexes in cystic
# fibrosis: decreased uptake of the complexes by fibroblasts in
# culture.
#
#  Inhibitory effect of cystic fibrosis serum on pseudomonas
# phagocytosis by rabbit and human alveolar macrophages.
#
#  Serum ciliotoxic activity in mutant mice with some hereditary
# alterations resembling cystic fibrosis.
#
#  Binding of 125I-labeled proteinases to plasma proteins in cystic
# fibrosis.
#
#  Serum salivary amylase in cystic fibrosis [letter].
#
#  Development of an improved tracheal explant bioassay for the
# detection of the ciliary dyskinesia factor in cystic fibrosis serum.
#
#  Laser light-scattering spectroscopy: preliminary results on bioassay
# of cystic fibrosis factor(s).
#
#  Cystic fibrosis serum effect on the short circuit current of rat
# jejunum.
#
#  Detection of cystic fibrosis protein by isoelectric focusing of
# serum [letter].
#
#  Cystic fibrosis protein, a confirmed diagnostic marker for detecting
# heterozygote carriers: significance in relation to future screening
# and to a proposed primary defect in alpha 2-macroglobulin.
#
#  Serum factor in cystic fibrosis: correlation with clinical
# parameters.
#
#  Intravenous linoleic acid supplementation in children with cystic
# fibrosis.
#
#  The chest roentgenogram in cystic fibrosis: a new scoring system.
#
#  Negative effects of oral fatty acid supplementation on sweat
# chloride in cystic fibrosis.
#
#  Hypoelectrolytemia and metabolic alkalosis in infants with cystic
# fibrosis.
#
#  Multifocal myocardial necrosis and fibrosis in pancreatic diseases
# of children.
#
#  Vitamin E: where do we stand?.
#
#  Metabolic alkalosis in infants with cystic fibrosis [letter].
#
#  An evaluation of the forced expiration technique as an adjunct to
# postural drainage.
#
#  A rapid procedure for the large scale purification of elastase and
# cathepsin G from human sputum.
#
#  Mitrochondrial NADH dehydrogenase in cystic fibrosis.
#
#  Cystic fibrosis: potential management through manipulation of the
# secretory process in affected exocrine glands.
#
#  Changing patterns of genetic counseling in a cystic fibrosis center.
#
#  New test to detect carriers of gene for cystic fibrosis [news].
#
#  Cystic fibrosis--its surgical presentation.
#
#  Chemotherapy of chronic infections with mucoid Pseudomonas
# aeruginosa in lower airways of patients with cystic fibrosis.
#
#  Proteins in bronchial secretion of children with chronic pulmonary
# diseases.  I. Relation to clinical diagnosis.
#
#  Proteins in bronchial secretion of children with chronic pulmonary
# diseases.  II.  Relation to bronchoscopic and bronchographic
# examination.
#
#  Killing of fibroblasts by dexamethasone or dibutyryl adenosine
# 3',5'-monophosphate is not a valid test for cystic fibrosis.
#
#  Premature senescence in cultured skin fibroblasts from subjects with
# cystic fibrosis.
#
#  Cystic fibrosis in adolescents and young adults.
#
#  Implications of cystic fibrosis for health services and the
# afflicted.
#
#  Cystic fibrosis: diagnosis, treatment, and prognosis.
#
#  Distal splenorenal shunt for decompression of portal hypertension in
# children with cystic fibrosis.
#
#  Cystic fibrosis: review of investigations of the mucociliary
# inhibitor.
#
#  "Small airways disease" in children: no test is best.
#
#  Detection of a lectin in the blood of cystic fibrosis homozygotes
# and heterozygotes.
#
#  Deficiencies of essential fatty acids and vitamin E in cystic
# fibrosis.

# %%
#Processador B - SAX - Títulos
import xml.sax

lista_titulos = []

class TitleHandler(xml.sax.ContentHandler):
    def startElement(self , name , attrs):
        self.title = ''
#        print(name)
        self.current = name
        if name == 'RECORD':
            print(f'-- Record -- ')
    def characters(self,content):
        if self.current == 'TITLE':
            self.title += content
    def endElement(self,name):
        if self.current == 'TITLE':
            print("TITLE: {}".format(self.title))
        self.current = ''
        if self.title!= '':
            lista_titulos.append("TITLE: {}".format(self.title))

handler = TitleHandler()
parser = xml.sax.make_parser()
parser.setContentHandler(handler)
parser.parse(full_file)

with open('titulos.txt', 'w') as f:
    for titulo in lista_titulos:
        f.write(titulo)
        f.write('\n')
# Out:
# -- Record --
# TITLE: 'Rusters'.  The corrosive action of palmar sweat: I. Sodium chloride
# in sweat.
# -- Record --
# TITLE: Inflammatory middle ear diseases in patients with cystic fibrosis.
# -- Record --
# TITLE: Precipitating antibodies against Escherichia coli, Bacteroides
# fragilis ss.  thetaiotaomicron and Pseudomonas aeruginosa in serum
# from normal persons and cystic fibrosis patients, determined by
# means of crossed immunoelectrophoresis.
# -- Record --
# TITLE: Exocrine pancreatic insufficiency, small intestinal dysfunction and
# protein intolerance.  A chance occurrence or a connection?.
# -- Record --
# TITLE: Increased intracranial pressure in infants with cystic fibrosis
# [letter].
# -- Record --
# TITLE: Precipitating antibodies against Haemophilus influenzae and
# Staphylococcus aureus in sputum and serum from patients with cystic
# fibrosis.
# -- Record --
# TITLE: IgA and IgG antibodies against surface antigens of Pseudomonas
# aeruginosa in sputum and serum from patients with cystic fibrosis.
# -- Record --
# TITLE: Activated complement in the sputum from patients with cystic
# fibrosis.
# -- Record --
# TITLE: Autoantibodies in serum and sputum from patients with cystic
# fibrosis.
# -- Record --
# TITLE: Chronic obstructive lung disease.
# -- Record --
# TITLE: Meconium in health and in disease.
# -- Record --
# TITLE: The effect of oral zinc supplementation on plasma levels of vitamin
# A and retinol-binding protein in cystic fibrosis.
# -- Record --
# TITLE: The fecal microflora and bile acids in children with cystic fibrosis.
# -- Record --
# TITLE: Serum glycine-conjugated bile acids in pediatric hepatobiliary
# disorders.
# -- Record --
# TITLE: Comparison of the chloride electrode and gravimetric chloride
# titration sweat tests.
# -- Record --
# TITLE: Comparison of the errors due to the use of gauze and the use of
# filter paper in the gravimetric chloride titration sweat test.
# -- Record --
# TITLE: Cystic fibrosis with acute hypoelectrolytemia and metabolic
# alkalosis in infancy.
# -- Record --
# TITLE: Demineralization in cystic fibrosis detected by direct photon
# absorptiometry.
# -- Record --
# TITLE: Psychosocial support for adults with cystic fibrosis: a group
# approach.
# -- Record --
# TITLE: Cystic fibrosis in adults.  75 cases and a review of 232 cases in
# the literature.
# -- Record --
# TITLE: Genetic counseling and prenatal diagnosis of cystic fibrosis
# [letter].
# -- Record --
# TITLE: Quantitative evaluation of the development of the exocrine pancreas
# in cystic fibrosis and control infants.
# -- Record --
# TITLE: A comparative study of inhaled atropine sulfate and isoproterenol
# hydrochloride in cystic fibrosis.
# -- Record --
# TITLE: The pulmonary circulation: remodeling in growth and disease.  The
# 1978 J. Burns Amberson lecture.
# -- Record --
# TITLE: Aspergillosis and atopy in cystic fibrosis.
# -- Record --
# TITLE: Maximal expiratory flows after postural drainage.
# -- Record --
# TITLE: Relationship between response to exercise and allergy in patients
# with cystic fibrosis.
# -- Record --
# TITLE: Radioimmunoassay of trypsin.  A new aid in the assessment of
# pancreatic function.
# -- Record --
# TITLE: Endobronchial balloon tamponade of hemoptysis in patients with
# cystic fibrosis.
# -- Record --
# TITLE: Antimicrobial susceptibilities of rough, smooth, and mucoid colony
# types of Pseudomonas isolated from cystic fibrosis patients.
# -- Record --
# TITLE: Results of 10 years of screening of newborn infants for inherited
# metabolic diseases in the province of Limburg (Belgium).
# -- Record --
# TITLE: Comparative trial of manual and mechanical percussion technique with
# gravity-assisted bronchial drainage in patients with cystic fibrosis.
# -- Record --
# TITLE: Paediatric Research Society.  Plymouth, 15 and 16 September 1978:
# Abstracts.
# -- Record --
# TITLE: Screening for cystic fibrosis in the newborn by meconium analysis.
# -- Record --
# TITLE: Pulmonary candidiasis in cystic fibrosis.
# -- Record --
# TITLE: Intestinal bile salts in cystic fibrosis: studies in the patient and
# experimental animal.
# -- Record --
# TITLE: Possible hazard of timed-release aspirin in a patient with
# pancreatic insufficiency.
# -- Record --
# TITLE: Cystic fibrosis with brain abscess.
# -- Record --
# TITLE: Cystic fibrosis and hearing loss.
# -- Record --
# TITLE: Vocational development and adjustment of adolescents with cystic
# fibrosis.
# -- Record --
# TITLE: Pharmacokinetics of azlocillin in children with cystic fibrosis.
# -- Record --
# TITLE: Dying children need help too.
# -- Record --
# TITLE: Cystic fibrosis: is it relevant to family practitioners?.
# -- Record --
# TITLE: Inhibition of Tamm-Horsfall glycoprotein induction of alkaline
# phosphatase in cystic fibrosis fibroblasts by medium conditioned by
# normal cells.
# -- Record --
# TITLE: Antibody responses to influenza virus vaccine in patients with
# cystic fibrosis.
# -- Record --
# TITLE: Biological activities of cystic fibrosis serum.  III.  CF serum
# induced uptake of 45Ca++ by rabbit tracheal explants.
# -- Record --
# TITLE: Differential concanavalin A binding of cystic fibrosis and normal
# liver alpha-L-fucosidase.
# -- Record --
# TITLE: Enzyme immunoassay of albumin as an aid to the diagnosis of cystic
# fibrosis in the newborn human [proceedings].
# -- Record --
# TITLE: Induction of alkaline phosphatase in cultured human fibroblasts.
# Comparison of normal cells and those from patients with cystic
# fibrosis.
# -- Record --
# TITLE: Plasma membrane lipids of human diploid fibroblasts from normal
# individuals and patients with cystic fibrosis.
# -- Record --
# TITLE: 2. Theories of genetic causation in human disease.
# -- Record --
# TITLE: Bronchial artery embolization in the control of massive haemoptysis.
# -- Record --
# TITLE: Cystic fibrosis in adults [editorial].
# -- Record --
# TITLE: New mechanical aid to physiotherapy in cystic fibrosis.
# -- Record --
# TITLE: Evaluation of the forced expiration technique as an adjunct to
# postural drainage in treatment of cystic fibrosis.
# -- Record --
# TITLE: Dying children need help too.
# -- Record --
# TITLE: Nocturnal elemental diet for retarded growth in a patient with
# cystic fibrosis.
# -- Record --
# TITLE: Lung function abnormalities in cystic fibrosis and changes during
# growth.
# -- Record --
# TITLE: The role of nutritional status, airway obstruction, hypoxia and
# abnormalities in serum lipid composition in limiting exercise
# tolerance in children with cystic fibrosis.
# -- Record --
# TITLE: One breath at a time: a family teaching program for children with
# cystic fibrosis.
# -- Record --
# TITLE: Noninvasive radionuclide assessment of right ventricular performance
# in man.
# -- Record --
# TITLE: In vitro susceptibility of pseudomonas to four
# beta-lactamantibiotics (ampicillin, cephalothin, carbenicillin,
# piperacillin), to four aminoglycosides (kanamycin, amikacin,
# gentamicin, tobramycin) and to colimycin.
# -- Record --
# TITLE: Echocardiographic profiles of the long-term cardiac changes in
# cystic fibrosis.
# -- Record --
# TITLE: Lymphocytic acid-hydrolases and response to mitogens in cystic
# fibrosis.
# -- Record --
# TITLE: Measurement of regional lung function by tetrapolar electrical
# impedance plethysmography.
# -- Record --
# TITLE: Evaluation of the single-breath diffusing capacity in asthma and
# cystic fibrosis.
# -- Record --
# TITLE: Echocardiographic abnormalities in patients with cystic fibrosis.
# -- Record --
# TITLE: Response to bronchial provocation and exercise in children with
# cystic fibrosis.
# -- Record --
# TITLE: IgE mediated hypersensitivity to pancreatic extract (PE) in parents
# of cystic fibrosis (CF) children.
# -- Record --
# TITLE: A study of erythrocyte fatty acids, adenosinetriphosphatase and
# acetylcholinesterase in cystic fibrosis.
# -- Record --
# TITLE: Measurement of 4-hydroxyphenylacetic aciduria as a screening test
# for small-bowel disease.
# -- Record --
# TITLE: Quality of sweat test performance in the diagnosis of cystic
# fibrosis.
# -- Record --
# TITLE: Secretion of beta-N-acetylglucosaminidase isoenzymes by cultured
# cystic fibrosis fibroblasts.
# -- Record --
# TITLE: Glycosidases in serum of cystic fibrosis patients.
# -- Record --
# TITLE: Carboxypeptidase B activity of cultured skin fibroblasts and
# relationship to cystic fibrosis.
# -- Record --
# TITLE: Decreased sialic acid and altered binding to lectins of purified
# alpha 2-macroglobulin from patients with cystic fibrosis.
# -- Record --
# TITLE: Abnormal distribution of alpha-L-fucosidase in cystic fibrosis:
# decreased activity in serum.
# -- Record --
# TITLE: Electrolytes and norepinephrine levels in blood of patients with
# cystic fibrosis.
# -- Record --
# TITLE: Primary amniotic fluid cell, skin fibroblast and liver
# alpha-L-fucosidase and its relation to cystic fibrosis.
# -- Record --
# TITLE: Allergy in cystic fibrosis.
# -- Record --
# TITLE: Heterozygote advantage in cystic fibrosis: mosquito tests.
# -- Record --
# TITLE: Deficiency of serum carboxypeptidase B-like (anaphylatoxin
# inactivator, carboxypeptidase N) activity in sera from patients with
# cystic fibrosis.
# -- Record --
# TITLE: False-positive 111In-labeled leukocyte scan in cystic fibrosis.
# -- Record --
# TITLE: Study of the oligosaccharide units from mucus glycoproteins of
# meconium from normal infants and from cases of cystic fibrosis with
# meconium ileus.
# -- Record --
# TITLE: Pseudomonas aeruginosa infection: pathogenesis and therapy.
# -- Record --
# TITLE: Lipids in cystic fibrosis.
# -- Record --
# TITLE: Obstruction of the respiratory pathways, its evaluation by methods
# of functional examination of the lungs and development in patients
# with cystic fibrosis.
# -- Record --
# TITLE: Prenatal diagnosis of cystic fibrosis [letter].
# -- Record --
# TITLE: Clinical pharmacology in a paediatric hospital.
# -- Record --
# TITLE: Protease deficiency in plasma of patients with cystic fibrosis.
# Reduced reaction of 4-methylumbelliferylguanidinobenzoate with
# plasma of patients with cystic fibrosis.
# -- Record --
# TITLE: Evaluation of long term tobramycin therapy in patients with cystic
# fibrosis and advanced pulmonary disease.
# -- Record --
# TITLE: Cystic fibrosis: decreased thermostability of alpha-mannosidase in
# crude extracellular fluids of patients and carriers.
# -- Record --
# TITLE: Relationship between clinical conditions, radiographic findings and
# pulmonary functions in patients with cystic fibrosis.
# -- Record --
# TITLE: Complement in cystic fibrosis.
# -- Record --
# TITLE: Substance P plasma levels in pregnancy and in various clinical
# disorders.
# -- Record --
# TITLE: The effect of serum from patients with pancreatic disease on the
# short circuit current of rat jejunum.
# -- Record --
# TITLE: Defective cellular immunity to gram-negative bacteria in cystic
# fibrosis patients.
# -- Record --
# TITLE: High dosage tobramycin treatment of children with cystic fibrosis.
# Bacteriological effect and clinical ototoxicity.
# -- Record --
# TITLE: The immotile-cilia syndrome and other ciliary diseases.
# -- Record --
# TITLE: Cystic fibrosis.
# -- Record --
# TITLE: Tobramycin ototoxicity.  Repeated courses of high dosage treatment
# in children with cystic fibrosis.
# -- Record --
# TITLE: Round table discussion--treatment of lower respiratory tract
# infections with co-trimoxazole.
# -- Record --
# TITLE: Epidemiology of cystic fibrosis: a review.
# -- Record --
# TITLE: The impact of grief: a retrospective study of family function
# following loss of a child with cystic fibrosis.
# -- Record --
# TITLE: Synthesis of hemoglobin Aic and related minor hemoglobin by
# erythrocytes.  In vitro study of regulation.
# -- Record --
# TITLE: Serotypes and antibiotic susceptibilities of Pseudomonas aeruginosa
# isolates from single sputa of cystic fibrosis patients.
# -- Record --
# TITLE: Dietary problems associated with the care of chronically sick
# children.
# -- Record --
# TITLE: Inborn errors of metabolism: the need for sugar.
# -- Record --
# TITLE: Therapeutic possibilities in Pseudomonas infections.
# -- Record --
# TITLE: Multiple of isolates of Pseudomonas aeruginosa with differing
# antimicrobial susceptibility patterns from patients with cystic
# fibrosis.
# -- Record --
# TITLE: Summary of a workshop on infections in patients with cystic fibrosis.
# -- Record --
# TITLE: Sulfhydryl-mediated depression of ciliary activity: an adverse
# effect of acetylcysteine.
# -- Record --
# TITLE: Adult cystic fibrosis: a new therapeutic challenge for the primary
# care physician.
# -- Record --
# TITLE: Cystic fibrosis in Northern Ireland.
# -- Record --
# TITLE: Cutaneous necrotizing venulitis in patients with cystic fibrosis.
# -- Record --
# TITLE: HLA determinants in families with more than one member with cystic
# fibrosis [letter].
# -- Record --
# TITLE: Episodic arthritis in children with cystic fibrosis.
# -- Record --
# TITLE: Failure to thrive, anemia, and anasarca.
# -- Record --
# TITLE: Bronchial hyperreactivity in cystic fibrosis [letter].
# -- Record --
# TITLE: A peroral test of pancreatic insufficiency with
# 4-(N-acetyl-L-tyrosyl)aminobenzoic acid in children with cystic
# fibrosis.
# -- Record --
# TITLE: The effect of cimetidine on maldigestion in cystic fibrosis.
# -- Record --
# TITLE: Normal neutrophil and monocyte chemotaxis in patients with cystic
# fibrosis.
# -- Record --
# TITLE: Hyperuricemia in cystic fibrosis [letter].
# -- Record --
# TITLE: Bronchial artery embolization in cystic fibrosis; technique and
# long-term results.
# -- Record --
# TITLE: Reliability of sweat test in cystic fibrosis [letter].
# -- Record --
# TITLE: 25-Hydroxycholecalciferol levels in patients with cystic fibrosis.
# -- Record --
# TITLE: Reduced serum 25-hydroxyvitamin D concentration and disordered
# mineral metabolism in patients with cystic fibrosis.
# -- Record --
# TITLE: Serum concentrations of 25-hydroxyvitamin D and
# 24,25-dihydroxyvitamin D in patients with cystic fibrosis.
# -- Record --
# TITLE: Atypical cystic fibrosis of the pancreas with normal levels of sweat
# chloride and minimal pancreatic lesions.
# -- Record --
# TITLE: Noninvasive evaluation of ventricular function in cystic fibrosis.
# -- Record --
# TITLE: Aminoglycoside clearance in patients with cystic fibrosis [letter].
# -- Record --
# TITLE: A placebo-controlled trial of cephalexin therapy in the ambulatory
# management of patients with cystic fibrosis.
# -- Record --
# TITLE: False positive sweat test, malnutrition, and the Mauriac syndrome.
# -- Record --
# TITLE: Cystic fibrosis in two black children with sickle cell anemia.
# -- Record --
# TITLE: Cystic fibrosis and malnutrition.
# -- Record --
# TITLE: Preatherosclerotic aortic lesions in cystic fibrosis.
# -- Record --
# TITLE: PABA-test for diagnosis of exocrine pancreatic insufficiency
# [letter].
# -- Record --
# TITLE: Brain abscess and cystic fibrosis.
# -- Record --
# TITLE: Meconium ileus: laparotomy without resection, anastomosis, or
# enterostomy.
# -- Record --
# TITLE: The effect of histamine, metiamide and cystic fibrosis factor on the
# electrophysiological properties of the frog's gastric mucosa
# [proceedings].
# -- Record --
# TITLE: The chronically ligated submandibular salivary duct of the rabbit as
# a possible model for cystic fibrosis [proceedings].
# -- Record --
# TITLE: Sweat tests [letter].
# -- Record --
# TITLE: The sweat test for cystic fibrosis [letter].
# -- Record --
# TITLE: Immunoreactive serum trypsin in diseases of the pancreas.
# -- Record --
# TITLE: Differential pathology of nasal polyps in cystic fibrosis and atopy.
# -- Record --
# TITLE: Sensitive trypsin assay for dried-blood specimens as a screening
# procedure for early detection of cystic fibrosis.
# -- Record --
# TITLE: Detection of cystic fibrosis with plasma hydrolases [letter].
# -- Record --
# TITLE: Dried blood spot screening for cystic fibrosis [letter].
# -- Record --
# TITLE: Age dependence of serum angiotensin-converting enzyme activity
# [letter].
# -- Record --
# TITLE: Methylumbelliferyl-guanidinobenzoate reactive proteases and prenatal
# diagnosis of cystic fibrosis [letter].
# -- Record --
# TITLE: Screening for cystic fibrosis [letter].
# -- Record --
# TITLE: Serum-angiotensin-converting-enzyme in chronic granulomatous disease
# [letter].
# -- Record --
# TITLE: Dried-blood spot screening for cystic fibrosis in the newborn.
# -- Record --
# TITLE: Allergy and bronchial hyperreactivity in cystic fibrosis [editorial].
# -- Record --
# TITLE: Serum-immunoreactive-trypsin concentrations in cystic fibrosis
# [letter].
# -- Record --
# TITLE: Methylumbelliferyl-guanidinobenzoate reactive proteases in amniotic
# fluid: possible marker for cystic fibrosis [letter].
# -- Record --
# TITLE: Plasma hydrolases in cystic fibrosis [letter].
# -- Record --
# TITLE: Mechanical chest physiotherapy [editorial].
# -- Record --
# TITLE: Detection of cystic fibrosis homozygotes and heterozygotes with
# plasma [letter].
# -- Record --
# TITLE: Arginine esterase in amniotic fluid: possible marker for cystic
# fibrosis [letter].
# -- Record --
# TITLE: Detection of cystic fibrosis homozygotes and heterozygotes with
# plasma.
# -- Record --
# TITLE: Differential incorporation of 3H-thymidine into DNA in cultured skin
# fibroblasts derived from patients with cystic fibrosis and controls.
# -- Record --
# TITLE: Animal model for cystic fibrosis: pulmonary clearance of
# Staphylococcus aureus in mice treated with reserpine.
# -- Record --
# TITLE: Increased resistance to influenza as a possible source of
# heterozygote advantage in cystic fibrosis.
# -- Record --
# TITLE: Pathogenesis of cystic fibrosis: possible importance of alteration
# in epithelial surface topography.
# -- Record --
# TITLE: Alkaline phosphatase induction in cystic fibrosis fibroblasts
# [letter].
# -- Record --
# TITLE: Improved survival of patients with cystic fibrosis.
# -- Record --
# TITLE: Alkaline phosphatase induction in cystic fibrosis fibroblasts
# [letter].
# -- Record --
# TITLE: The short-term effects of chest physiotherapy on lung function tests
# in children with cystic fibrosis.
# -- Record --
# TITLE: Effect of four physiotherapy schedules on pulmonary function in
# children with cystic fibrosis.
# -- Record --
# TITLE: Relationship between clinical conditions, chest radiographic
# findings and respiratory function tests in cystic fibrosis.
# -- Record --
# TITLE: A new percussion aid for cystic fibrosis patients.
# -- Record --
# TITLE: The mechanism of autogenic drainage studied with flow volume curves.
# -- Record --
# TITLE: Intestinal lactase deficiency in newborns with cystic
# fibrosis--dietary consequences.
# -- Record --
# TITLE: Ultrastructure of the bronchial epithelium in children with cystic
# fibrosis.
# -- Record --
# TITLE: Recent research in cystic fibrosis.
# -- Record --
# TITLE: Relevance of second messengers in cystic fibrosis.
# -- Record --
# TITLE: Trace element malabsorption in exocrine pancreatic insufficiency.
# -- Record --
# TITLE: Prostaglandins and cystic fibrosis.
# -- Record --
# TITLE: Operational definition of cystic fibrosis.  I.
# -- Record --
# TITLE: Alpha-glucosidase in cystic fibrosis.
# -- Record --
# TITLE: Postprandial total serum bile acid concentrations in cystic fibrosis.
# -- Record --
# TITLE: The cystic fibrosis gene, IgE and IgG4.
# -- Record --
# TITLE: Bronchial reactivity in children with cystic fibrosis and other
# recurrent or chronic bronchopulmonary diseases.
# -- Record --
# TITLE: Increased serum TSH response to TRH in cystic fibrosis.
# -- Record --
# TITLE: Factors influencing the frequency of cystic fibrosis in South West
# Africa.
# -- Record --
# TITLE: The effect of cystic fibrosis and non-cystic fibrosis plasma on
# electrophysiological responses in isolated frog gastric mucosa.
# -- Record --
# TITLE: Fatty acid supplementation in cystic fibrosis.
# -- Record --
# TITLE: Bronchial provocation tests in cystic fibrosis.
# -- Record --
# TITLE: The local immune status in cystic fibrosis.
# -- Record --
# TITLE: Complement activation and pulmonary inflammation in CF patients.
# -- Record --
# TITLE: Protein, IgA, secretory IgA, IgG and electrolytes as parameters of
# parotid gland function in children with cystic fibrosis.
# -- Record --
# TITLE: Precipitating antibodies against E. coli, B. fragilis, and P.
# aeruginosa in CF patients and normal persons determined by means of
# crossed immunoelectrophoresis.
# -- Record --
# TITLE: Screening for cystic fibrosis in the newborn.
# -- Record --
# TITLE: Sulphated glycoproteins in the pancreas.
# -- Record --
# TITLE: An evaluation of the meconium 'lactase test' for the detection of
# cystic fibrosis in the newborn.
# -- Record --
# TITLE: Two children with cystic fibrosis and myocardial fibrosis.
# -- Record --
# TITLE: Chemical comparison of normal and cystic fibrosis meconium: a
# quantitative and qualitative analysis of carbohydrate splitting
# enzymes.
# -- Record --
# TITLE: The use and abuse of antibiotics, including in management of
# pulmonary manifestations in cystic fibrosis.
# -- Record --
# TITLE: Long-term tobramycin therapy in patients with cystic fibrosis and
# advanced pulmonary disease.
# -- Record --
# TITLE: Bioavailability of oral antibiotics in cystic fibrosis.
# -- Record --
# TITLE: Progress in screening.
# -- Record --
# TITLE: Diagnosing cystic fibrosis in adults [letter].
# -- Record --
# TITLE: Case records of the Massachusetts General Hospital.  Weekly
# clinicopathological exercises.  Case 8-1979.
# -- Record --
# TITLE: Mitochondrial calcium uptake and oxygen consumption in cystic
# fibrosis.
# -- Record --
# TITLE: Cystic fibrosis and erroneous sweat tests.
# -- Record --
# TITLE: Cystic fibrosis: a disease of unknown causes.
# -- Record --
# TITLE: Prone immersion physical exercise therapy in three children with
# cystic fibrosis: a pilot study.
# -- Record --
# TITLE: Anemia, hypoproteinemia and edema in an infant with cystic fibrosis.
# -- Record --
# TITLE: Serum vitamin D and related mineral metabolism in cystic fibrosis.
# -- Record --
# TITLE: The pyridine scale for clinical measurement of olfactory threshold:
# a quantitative reevaluation.
# -- Record --
# TITLE: Cystic fibrosis in adults: an autopsy study.
# -- Record --
# TITLE: Invited review.  The technique and scope of electron-probe X-ray
# analysis in pathology.
# -- Record --
# TITLE: Genetic aspects of pediatric lung disease.
# -- Record --
# TITLE: Perspectives in cystic fibrosis.
# -- Record --
# TITLE: Increased heparin binding in cystic fibrosis: a reflection of
# altered glycoprotein biosynthesis?.
# -- Record --
# TITLE: The chronically reserpinized rat as an animal model for cystic
# fibrosis: I. Acute effect of isoproterenol and pilocarpine upon
# pulmonary lavage fluid.
# -- Record --
# TITLE: Altered polyamine metabolism in cystic fibrosis.
# -- Record --
# TITLE: Chronically reserpinized rat as a model for cystic fibrosis: Na+
# transport inhibitory effect in submaxillary saliva.
# -- Record --
# TITLE: Evidence against a specific effect of serum from patients with
# cystic fibrosis on sodium-dependent glucose transport in the rat
# jejunum.
# -- Record --
# TITLE: Altered intracellular calcium in fibroblasts from patients with
# cystic fibrosis and heterozygotes.
# -- Record --
# TITLE: Anomalous alpha 2-macroglobulin-protease complexes in cystic
# fibrosis: decreased uptake of the complexes by fibroblasts in
# culture.
# -- Record --
# TITLE: Inhibitory effect of cystic fibrosis serum on pseudomonas
# phagocytosis by rabbit and human alveolar macrophages.
# -- Record --
# TITLE: Serum ciliotoxic activity in mutant mice with some hereditary
# alterations resembling cystic fibrosis.
# -- Record --
# TITLE: Binding of 125I-labeled proteinases to plasma proteins in cystic
# fibrosis.
# -- Record --
# TITLE: Serum salivary amylase in cystic fibrosis [letter].
# -- Record --
# TITLE: Development of an improved tracheal explant bioassay for the
# detection of the ciliary dyskinesia factor in cystic fibrosis serum.
# -- Record --
# TITLE: Laser light-scattering spectroscopy: preliminary results on bioassay
# of cystic fibrosis factor(s).
# -- Record --
# TITLE: Cystic fibrosis serum effect on the short circuit current of rat
# jejunum.
# -- Record --
# TITLE: Detection of cystic fibrosis protein by isoelectric focusing of
# serum [letter].
# -- Record --
# TITLE: Cystic fibrosis protein, a confirmed diagnostic marker for detecting
# heterozygote carriers: significance in relation to future screening
# and to a proposed primary defect in alpha 2-macroglobulin.
# -- Record --
# TITLE: Serum factor in cystic fibrosis: correlation with clinical
# parameters.
# -- Record --
# TITLE: Intravenous linoleic acid supplementation in children with cystic
# fibrosis.
# -- Record --
# TITLE: The chest roentgenogram in cystic fibrosis: a new scoring system.
# -- Record --
# TITLE: Negative effects of oral fatty acid supplementation on sweat
# chloride in cystic fibrosis.
# -- Record --
# TITLE: Hypoelectrolytemia and metabolic alkalosis in infants with cystic
# fibrosis.
# -- Record --
# TITLE: Multifocal myocardial necrosis and fibrosis in pancreatic diseases
# of children.
# -- Record --
# TITLE: Vitamin E: where do we stand?.
# -- Record --
# TITLE: Metabolic alkalosis in infants with cystic fibrosis [letter].
# -- Record --
# TITLE: An evaluation of the forced expiration technique as an adjunct to
# postural drainage.
# -- Record --
# TITLE: A rapid procedure for the large scale purification of elastase and
# cathepsin G from human sputum.
# -- Record --
# TITLE: Mitrochondrial NADH dehydrogenase in cystic fibrosis.
# -- Record --
# TITLE: Cystic fibrosis: potential management through manipulation of the
# secretory process in affected exocrine glands.
# -- Record --
# TITLE: Changing patterns of genetic counseling in a cystic fibrosis center.
# -- Record --
# TITLE: New test to detect carriers of gene for cystic fibrosis [news].
# -- Record --
# TITLE: Cystic fibrosis--its surgical presentation.
# -- Record --
# TITLE: Chemotherapy of chronic infections with mucoid Pseudomonas
# aeruginosa in lower airways of patients with cystic fibrosis.
# -- Record --
# TITLE: Proteins in bronchial secretion of children with chronic pulmonary
# diseases.  I. Relation to clinical diagnosis.
# -- Record --
# TITLE: Proteins in bronchial secretion of children with chronic pulmonary
# diseases.  II.  Relation to bronchoscopic and bronchographic
# examination.
# -- Record --
# TITLE: Killing of fibroblasts by dexamethasone or dibutyryl adenosine
# 3',5'-monophosphate is not a valid test for cystic fibrosis.
# -- Record --
# TITLE: Premature senescence in cultured skin fibroblasts from subjects with
# cystic fibrosis.
# -- Record --
# TITLE: Cystic fibrosis in adolescents and young adults.
# -- Record --
# TITLE: Implications of cystic fibrosis for health services and the
# afflicted.
# -- Record --
# TITLE: Cystic fibrosis: diagnosis, treatment, and prognosis.
# -- Record --
# TITLE: Distal splenorenal shunt for decompression of portal hypertension in
# children with cystic fibrosis.
# -- Record --
# TITLE: Cystic fibrosis: review of investigations of the mucociliary
# inhibitor.
# -- Record --
# TITLE: "Small airways disease" in children: no test is best.
# -- Record --
# TITLE: Detection of a lectin in the blood of cystic fibrosis homozygotes
# and heterozygotes.
# -- Record --
# TITLE: Deficiencies of essential fatty acids and vitamin E in cystic
# fibrosis.
